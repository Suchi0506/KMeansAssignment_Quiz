# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchi0506/KMeansAssignment_Quiz/blob/main/KMeansAssignmentQuiz_Intellipat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-76e6a565-5ae2-4e48-a4b7-b17288c66980" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76e6a565-5ae2-4e48-a4b7-b17288c66980">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv('Live.csv')
df.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
# Dropping the columns 'Column1', 'Column2',	'Column3',	'Column4'
df = df.drop(['Column1', 'Column2', 'Column3', 'Column4'], axis=1)
df.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys
# 0          1         1           0
# 1          0         0           0
# ...

# %%
# Number of columns containing null data
df.isnull().sum()
# Out:
# status_id           0
# status_type         0
# status_published    0
# num_reactions       0
# num_comments        0
# num_shares          0
# num_likes           0
# num_loves           0
# num_wows            0
# num_hahas           0
# num_sads            0
# num_angrys          0
# dtype: int64

# %%
# HCount of status ids that are unique
df['status_id'].nunique()
# Out:
# 6997

# %%
# Count of video post has been made for live selling
df[df['status_type'] == 'video'].count()
# Out:
# status_id           2334
# status_type         2334
# status_published    2334
# num_reactions       2334
# num_comments        2334
# num_shares          2334
# num_likes           2334
# num_loves           2334
# num_wows            2334
# num_hahas           2334
# num_sads            2334
# num_angrys          2334
# dtype: int64

# %%
# Number of likes have been given to the photo posted on 4/19/2018 at 22:26?
df[(df['status_type'] == 'photo') & (df['status_published'] == '4/19/2018 22:26')]['num_likes'].sum()
# Out:
# 379

# %%
# Count of total shares made for the video post that was posted on 7/15/2017 at 10:52?
df[(df['status_type'] == 'video') & (df['status_published'] == '7/15/2017 10:52')]['num_shares'].sum()
# Out:
# 167

# %%
colour=['red','blue','green','yellow','cyan']
n=0  for i in range(0,len(colour)):
plt.scatter(X[df['Clusters(5)']==i],Y[df['Clusters(5)']==i],s=10,c=colour[i])
plt.scatter(k.cluster_centers_[:,0] ,k.cluster_centers_[:,1], color='black')

# %% [markdown]
# **Perform the following operations on the dataset:***
# 1. Drop Status id and status published column.
# 2. Use a label encoder to encode the status type column.
# 3. Standardize the data using min-max scalar
# 4. Create a K means model for 2 clusters.
# 5. From the above model, what is the inter-cluster variance of the model?

# %%
df.drop(['status_id','status_published'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['status_type']=le.fit_transform(df['status_type'])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)

# %%
# Access the inertia (within-cluster variance)
kmeans.fit(df)
inertia = kmeans.inertia_

# Get the centroids of the clusters
centroids = kmeans.cluster_centers_

# Calculate the Euclidean distance between the two centroids
distance = np.linalg.norm(centroids[0] - centroids[1])

print("Inertia (within-cluster variance):", inertia)
print("Inter-cluster variance (distance between centroids):", distance)
# Out:
# Inertia (within-cluster variance): 240.06686397262683
# Inter-cluster variance (distance between centroids): 0.6430946979358005
